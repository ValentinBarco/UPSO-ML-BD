# %% [markdown]
# <a href="https://colab.research.google.com/github/ValentinBarco/UPSO-ML-BD/blob/main/Practica_de_Estadistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# Parámetros
muestras = 100

mediaX1 = 100
desvioX1 = 40

mediaY1 = 30
desvioY1 = 45

mediaX2 = 20
desvioX2 = 25

mediaY2 = 60
desvioY2 = 20

X1 = pd.Series(np.random.normal(loc=mediaX1, scale=desvioX1, size=muestras))
Y1 = pd.Series(np.random.normal(loc=mediaY1, scale=desvioY1, size=muestras))
Data1 = pd.DataFrame({'color':'red', 'target':0, 'x':X1, 'y':Y1})


X2 = pd.Series(np.random.normal(loc=mediaX2, scale=desvioX2, size=muestras))
Y2 = pd.Series(np.random.normal(loc=mediaY2, scale=desvioY2, size=muestras))
Data2 = pd.DataFrame({'color':'blue', 'target':1, 'x':X2, 'y':Y2})

Dataset = pd.concat([Data1, Data2], ignore_index=True, axis=0)


marker_size = 10


fig = go.Figure()


fig.add_trace(go.Scatter(x=Data1['x'], y=Data1['y'], mode='markers',
                         marker=dict(color='red', size=marker_size), name='A'))


fig.add_trace(go.Scatter(x=Data2['x'], y=Data2['y'], mode='markers',
                         marker=dict(color='blue', size=marker_size), name='B'))


fig.update_layout(
    autosize=False,
    width=600,
    height=500,
    margin=dict(l=50, r=50, b=50, t=50)
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import plotly.graph_objects as go


muestras = 100

mediaX1 = 80
desvioX1 = 20

mediaY1 = 20
desvioY1 = 25

mediaX2 = 20
desvioX2 = 25

mediaY2 = 60
desvioY2 = 20


X1 = pd.Series(np.random.normal(loc=mediaX1, scale=desvioX1, size=muestras))
Y1 = pd.Series(np.random.normal(loc=mediaY1, scale=desvioY1, size=muestras))
Data1 = pd.DataFrame({'color':'red', 'target':0, 'x':X1, 'y':Y1})


X2 = pd.Series(np.random.normal(loc=mediaX2, scale=desvioX2, size=muestras))
Y2 = pd.Series(np.random.normal(loc=mediaY2, scale=desvioY2, size=muestras))
Data2 = pd.DataFrame({'color':'blue', 'target':1, 'x':X2, 'y':Y2})


Dataset = pd.concat([Data1, Data2], ignore_index=True, axis=0)

sns.jointplot(data=Dataset, x="x", y="y", kind="scatter", hue="target")

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# Parámetros
muestras = 100

mediaX1 = 80
desvioX1 = 20

mediaY1 = 20
desvioY1 = 25

mediaX2 = 20
desvioX2 = 25

mediaY2 = 60
desvioY2 = 20


X1 = pd.Series(np.random.normal(loc=mediaX1, scale=desvioX1, size=muestras))
Y1 = pd.Series(np.random.normal(loc=mediaY1, scale=desvioY1, size=muestras))
Data1 = pd.DataFrame({'color':'red', 'target':0, 'x':X1, 'y':Y1})


X2 = pd.Series(np.random.normal(loc=mediaX2, scale=desvioX2, size=muestras))
Y2 = pd.Series(np.random.normal(loc=mediaY2, scale=desvioY2, size=muestras))
Data2 = pd.DataFrame({'color':'blue', 'target':1, 'x':X2, 'y':Y2})


Dataset = pd.concat([Data1, Data2], ignore_index=True, axis=0)

sns.jointplot(data=Dataset, x="x", y="y",  kind='kde', hue="target")

# %%
Dataset
# Out:
#     color  target           x          y
# 0     red       0   96.447408  33.434648
# 1     red       0  103.297552  57.989348
# 2     red       0  104.444306 -14.873563
# 3     red       0   67.255342  26.824680
# 4     red       0   65.880639 -13.965935
# ..    ...     ...         ...        ...
# 195  blue       1   45.470273  45.082369
# 196  blue       1   31.080426  32.363277
# 197  blue       1   10.827844  62.246307
# 198  blue       1  -52.423673  82.391128
# 199  blue       1   12.084950  36.768556
#
# [200 rows x 4 columns]

# %%
def calculate_zscore(series):
    return (series - series.mean()) / series.std()


Data1['zscore_x'] =  calculate_zscore(Data1['x'])

# Métricas para el grupo 1 (Data1)
metrics_data1_x = {
    'Media': Data1['x'].mean(),
    'Mediana': Data1['x'].median(),
    'Desviación Estándar': Data1['x'].std(),
    'Mínimo': Data1['x'].min(),
    'Máximo': Data1['x'].max()
}

metrics_data1_y = {
    'Media': Data1['y'].mean(),
    'Mediana': Data1['y'].median(),
    'Desviación Estándar': Data1['y'].std(),
    'Mínimo': Data1['y'].min(),
    'Máximo': Data1['y'].max()
}
import pandas as pd


df_metrics = pd.DataFrame({
    'Data1 - x': metrics_data1_x,
    'Data1 - y': metrics_data1_y
})



df_metrics
# Out:
#                       Data1 - x  Data1 - y
# Media                 79.252148  18.814315
# Mediana               78.534092  19.856159
# Desviación Estándar   21.179450  25.004370
# Mínimo                33.107787 -37.771560
# Máximo               122.619263  67.499182

# %%
Data1[Data1['zscore_x']<-2]
# Out:
#             x  zscore_x
# 52  33.920902 -2.408380
# 62  34.705768 -2.367858

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()


data_uniform = np.random.uniform(low=0, high=1, size=1000)
data_normal = np.random.normal(loc=0, scale=1, size=1000)
data_binomial = np.random.binomial(n=10, p=0.1, size=1000)
data_poisson = np.random.poisson(lam=3, size=1000)
data_exponential = np.random.exponential(scale=1, size=1000)
data_chisquare = np.random.chisquare(df=2, size=1000)
data_beta = np.random.beta(a=5, b=2, size=1000)
data_gamma = np.random.gamma(shape=2, scale=1, size=1000)


fig, axs = plt.subplots(4, 2, figsize=(14, 14))


sns.kdeplot(data_uniform, ax=axs[0, 0], color='skyblue', shade=True)
axs[0, 0].set_title('Distribución Uniforme')

sns.kdeplot(data_normal, ax=axs[0, 1], color='salmon', shade=True)
axs[0, 1].set_title('Distribución Normal')

sns.kdeplot(data_binomial, ax=axs[1, 0], color='lightgreen', shade=True)
axs[1, 0].set_title('Distribución Binomial')

sns.kdeplot(data_poisson, ax=axs[1, 1], color='gold', shade=True)
axs[1, 1].set_title('Distribución Poisson')

sns.kdeplot(data_exponential, ax=axs[2, 0], color='orchid', shade=True)
axs[2, 0].set_title('Distribución Exponencial')

sns.kdeplot(data_chisquare, ax=axs[2, 1], color='tan', shade=True)
axs[2, 1].set_title('Distribución Chi Cuadrado')

sns.kdeplot(data_beta, ax=axs[3, 0], color='lightcoral', shade=True)
axs[3, 0].set_title('Distribución Beta')

sns.kdeplot(data_gamma, ax=axs[3, 1], color='lightskyblue', shade=True)
axs[3, 1].set_title('Distribución Gamma')

# Ajustar el layout
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-42-6c8fa678afde>:22: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#
# <ipython-input-42-6c8fa678afde>:25: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#
# <ipython-input-42-6c8fa678afde>:28: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#
# <ipython-input-42-6c8fa678afde>:31: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#
# <ipython-input-42-6c8fa678afde>:34: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# ...
